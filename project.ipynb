# %%
import pandas as pd
data=pd.read_csv(r"C:\Users\User\Downloads\Bangalore_AQI_Dataset.csv")
data
# Out:
#            City        Date  AQI  PM2.5    PM10     NO2     SO2     CO     O3
# 0     Bangalore  01-01-2018   68   37.4   73.44   56.44   77.52   0.71   64.6
# 1     Bangalore  02-01-2018   76   41.8   82.08   63.08   86.64   0.80   72.2
# 2     Bangalore  03-01-2018   70   38.5   75.60   58.10   79.80   0.74   66.5
# 3     Bangalore  04-01-2018   78   42.9   84.24   64.74   88.92   0.82   74.1
# 4     Bangalore  05-01-2018   82   45.1   88.56   68.06   93.48   0.86   77.9
# ...         ...         ...  ...    ...     ...     ...     ...    ...    ...
# 3015  Bangalore  06-09-2018  392  423.5  588.50  463.50  431.50  23.10  210.5
# 3016  Bangalore  07-09-2018  394  426.0  591.00  466.00  434.00  23.30  211.5
# 3017  Bangalore  08-09-2018  396  428.5  593.50  468.50  436.50  23.50  212.5
# 3018  Bangalore  09-09-2018  398  431.0  596.00  471.00  439.00  23.70  213.5
# 3019  Bangalore  10-09-2018  400  433.5  598.50  473.50  441.50  23.90  214.5
#
# [3020 rows x 9 columns]

# %%
data.isnull().sum()
# Out:
# City     0
# Date     0
# AQI      0
# PM2.5    0
# PM10     0
# NO2      0
# SO2      0
# CO       0
# O3       0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
x=data[["PM2.5","PM10","NO2","SO2","CO","O3"]]
x
# Out:
#       PM2.5    PM10     NO2     SO2     CO     O3
# 0      37.4   73.44   56.44   77.52   0.71   64.6
# 1      41.8   82.08   63.08   86.64   0.80   72.2
# 2      38.5   75.60   58.10   79.80   0.74   66.5
# 3      42.9   84.24   64.74   88.92   0.82   74.1
# 4      45.1   88.56   68.06   93.48   0.86   77.9
# ...     ...     ...     ...     ...    ...    ...
# 3015  423.5  588.50  463.50  431.50  23.10  210.5
# 3016  426.0  591.00  466.00  434.00  23.30  211.5
# 3017  428.5  593.50  468.50  436.50  23.50  212.5
# 3018  431.0  596.00  471.00  439.00  23.70  213.5
# 3019  433.5  598.50  473.50  441.50  23.90  214.5
#
# [3020 rows x 6 columns]

# %%
y=data[["AQI"]]
y
# Out:
#       AQI
# 0      68
# 1      76
# 2      70
# 3      78
# 4      82
# ...   ...
# 3015  392
# 3016  394
# 3017  396
# 3018  398
# 3019  400
#
# [3020 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2)
x_test
# Out:
#        PM2.5    PM10     NO2     SO2     CO      O3
# 1297   25.85   50.76   39.01   53.58   0.49   44.65
# 1211   52.25  102.60   78.85  108.30   1.00   90.25
# 2582   96.50  174.00   86.00  128.00   1.80   75.00
# 2976  326.00  491.00  366.00  334.00  15.30  171.50
# 2098   21.45   42.12   32.37   44.46   0.41   37.05
# ...      ...     ...     ...     ...    ...     ...
# 2616  100.00  180.00   96.00  130.00   2.10   77.50
# 1417   40.70   79.92   61.42   84.36   0.78   70.30
# 77     40.15   78.84   60.59   83.22   0.77   69.35
# 2891  246.50  397.00  275.00  260.50  10.00  145.00
# 1535   77.55  152.28  117.03  160.74   1.48  133.95
#
# [2416 rows x 6 columns]

# %%
import seaborn as sns
sns.histplot(data["AQI"])
# Out:
# <Axes: xlabel='AQI', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="AQI",y="PM2.5",data=data,hue="AQI")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="AQI",y="PM10",data=data,hue="AQI")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="AQI",y="SO2",data=data,hue="AQI")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="AQI",y="NO2",data=data,hue="AQI")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x="AQI",y="CO",data=data,hue="AQI")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
ll=LinearRegression()
ll.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ll.predict([[29.15,57.24,43.99,60.42,0.56,50.35]])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[52.62061058]])

# %%
import pickle
file=open("projectTrainmodifyLR.pkl","wb")
pickle.dump(ll,file)
file.close()

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
kn=KNeighborsRegressor(n_neighbors=5)
kn.fit(x_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
kn.predict([[29.15,57.24,43.99,60.42,0.56,50.35]])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([[53.]])

# %%
import pickle
file=open("projectTrainmodifyKNN.pkl","wb")
pickle.dump(kn,file)
file.close()

# %%
from sklearn.tree import DecisionTreeRegressor
dt= DecisionTreeRegressor()
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dt.predict([[29.15,57.24,43.99,60.42,0.56,50.35]])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([53.])

# %%
import pickle
file=open("projectTrainmodifyDT.pkl","wb")
pickle.dump(dt,file)
file.close()

# %%
from sklearn.ensemble import RandomForestRegressor
reg=RandomForestRegressor(n_estimators=100)
reg.fit(x_train,y_train)
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
reg.predict([[29.15,57.24,43.99,60.42,0.56,50.35]])
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([53.])

# %%
import pickle
file=open("projectTrainmodifyRan.pkl","wb")
pickle.dump(reg,file)
file.close()

# %%
data
# Out:
#            City      Date  AQI  PM2.5   PM10    NO2    SO2    CO     O3
# 0     Bangalore  01/01/18   68  37.40  73.44  56.44  77.52  0.71  64.60
# 1     Bangalore  02/01/18   76  41.80  82.08  63.08  86.64  0.80  72.20
# 2     Bangalore  03/01/18   70  38.50  75.60  58.10  79.80  0.74  66.50
# 3     Bangalore  04/01/18   78  42.90  84.24  64.74  88.92  0.82  74.10
# 4     Bangalore  05/01/18   82  45.10  88.56  68.06  93.48  0.86  77.90
# ...         ...       ...  ...    ...    ...    ...    ...   ...    ...
# 2551  Bangalore  27/12/24   54  29.70  58.32  44.82  61.56  0.57  51.30
# 2552  Bangalore  28/12/24   57  31.35  61.56  47.31  64.98  0.60  54.15
# 2553  Bangalore  29/12/24   70  38.50  75.60  58.10  79.80  0.74  66.50
# 2554  Bangalore  30/12/24   62  34.10  66.96  51.46  70.68  0.65  58.90
# 2555  Bangalore  31/12/24   65  35.75  70.20  53.95  74.10  0.68  61.75
#
# [2556 rows x 9 columns]

# %%
data.head(100)
# Out:
#          City      Date  AQI  PM2.5    PM10     NO2     SO2    CO      O3
# 0   Bangalore  01/01/18   68  37.40   73.44   56.44   77.52  0.71   64.60
# 1   Bangalore  02/01/18   76  41.80   82.08   63.08   86.64  0.80   72.20
# 2   Bangalore  03/01/18   70  38.50   75.60   58.10   79.80  0.74   66.50
# 3   Bangalore  04/01/18   78  42.90   84.24   64.74   88.92  0.82   74.10
# 4   Bangalore  05/01/18   82  45.10   88.56   68.06   93.48  0.86   77.90
# ..        ...       ...  ...    ...     ...     ...     ...   ...     ...
# 95  Bangalore  06/04/18  116  63.80  125.28   96.28  132.24  1.22  110.20
# 96  Bangalore  07/04/18  128  70.40  138.24  106.24  145.92  1.34  121.60
# 97  Bangalore  08/04/18  108  59.40  116.64   89.64  123.12  1.13  102.60
# 98  Bangalore  09/04/18   57  31.35   61.56   47.31   64.98  0.60   54.15
# 99  Bangalore  10/04/18   66  36.30   71.28   54.78   75.24  0.69   62.70
#
# [100 rows x 9 columns]
